# %% [markdown]
# <a href="https://colab.research.google.com/github/elfarizidan/Simple-cashier-menu-with-python/blob/main/Praktikum%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('Dataset.xlsx')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0       1709  CA-2017-123491 2017-10-30 2017-10-30  Standard Class
# 1       3783  CA-2017-165204 2017-11-13 2017-11-16    Second Class
# 2       7322  CA-2017-167626 2017-03-09 2017-07-09  Standard Class
# 3        356  CA-2016-138520 2016-08-04 2016-08-04  Standard Class
# 4       2586  CA-2015-121041 2015-03-11 2015-10-11  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    7312  CA-2015-162761 2015-09-10 2015-10-13  Standard Class
# 9990    7896  CA-2017-124744 2017-06-21 2017-06-25  Standard Class
# 9991    7955  CA-2014-138359 2014-01-04 2014-06-04  Standard Class
# 9992    8966  CA-2017-106691 2017-06-11 2017-12-11  Standard Class
# 9993    9753  US-2016-158680 2016-01-07 2016-02-07     First Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 0       JK-15205        Jamie Kunitz     Consumer  United States
# ...

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Row ID               9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   datetime64[ns]
#  3   Ship Date            9994 non-null   datetime64[ns]
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Country              9994 non-null   object
#  9   City                 9994 non-null   object
#  10  State                9994 non-null   object
#  11  Postal Code          9994 non-null   int64
#  12  Region               9994 non-null   object
#  13  Retail Sales People  9994 non-null   object
#  14  Product ID           9994 non-null   object
# ...

# %%
duplicates = df[df.duplicated()]
print("Duplikat yang ditemukan: \n", duplicates)
# Out:
# Duplikat yang ditemukan:
#  Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Retail Sales People, Product ID, Category, Sub-Category, Product Name, Returned, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 23 columns]

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], errors="coerce")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], errors="coerce")

numeric_colums = ["Sales", "Quantity", "Discount", "Profit"]
df[numeric_colums] = df[numeric_colums].apply(pd.to_numeric, errors="coerce")

df.dtypes
# Out:
# Row ID                          int64
# Order ID                       object
# Order Date             datetime64[ns]
# Ship Date              datetime64[ns]
# Ship Mode                      object
# Customer ID                    object
# Customer Name                  object
# Segment                        object
# Country                        object
# City                           object
# State                          object
# Postal Code                     int64
# Region                         object
# Retail Sales People            object
# Product ID                     object
# Category                       object
# Sub-Category                   object
# Product Name                   object
# Returned                       object
# Sales                         float64
# Quantity                        int64
# Discount                      float64
# Profit                        float64
# dtype: object

# %%
df_reduced = df[["Sales", "Quantity", "Discount", "Product Name", "Profit"]]

df_reduced.head()
# Out:
#    Sales  Quantity  Discount  \
# 0  7.420         2       0.0
# 1  8.904         3       0.2
# 2  8.904         3       0.2
# 3  8.260         2       0.0
# 4  6.608         2       0.2
#
#                                         Product Name  Profit
# 0  "While you Were Out" Message Book, One Form pe...  3.7100
# 1  "While you Were Out" Message Book, One Form pe...  3.3390
# 2  "While you Were Out" Message Book, One Form pe...  3.3390
# 3           #10 Gummed Flap White Envelopes, 100/Box  3.7996
# 4           #10 Gummed Flap White Envelopes, 100/Box  2.1476

# %%
missing_values_reduced = df_reduced.isnull().sum()
missing_values_reduced
# Out:
# Sales           0
# Quantity        0
# Discount        0
# Product Name    0
# Profit          0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_transformed = df_reduced.copy()
df_transformed[["Sales", "Quantity", "Discount", "Profit"]] = scaler.fit_transform(
    df_transformed[["Sales", "Quantity", "Discount", "Profit"]]
)

df_transformed.head()
# Out:
#       Sales  Quantity  Discount  \
# 0  0.000308  0.076923      0.00
# 1  0.000374  0.153846      0.25
# 2  0.000374  0.153846      0.25
# 3  0.000345  0.076923      0.00
# 4  0.000272  0.076923      0.25
#
#                                         Product Name    Profit
# 0  "While you Were Out" Message Book, One Form pe...  0.440247
# 1  "While you Were Out" Message Book, One Form pe...  0.440222
# 2  "While you Were Out" Message Book, One Form pe...  0.440222
# 3           #10 Gummed Flap White Envelopes, 100/Box  0.440253
# 4           #10 Gummed Flap White Envelopes, 100/Box  0.440143

# %%
# !pip install openpyxl

import pandas as pd
import matplotlib.pyplot as plt
# !pip install openpyxl

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel("Dataset.xlsx")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    1709  CA-2017-123491 2017-10-30 2017-10-30  Standard Class    JK-15205
# 1    3783  CA-2017-165204 2017-11-13 2017-11-16    Second Class    MN-17935
# 2    7322  CA-2017-167626 2017-03-09 2017-07-09  Standard Class    MY-18295
# 3     356  CA-2016-138520 2016-08-04 2016-08-04  Standard Class    JL-15505
# 4    2586  CA-2015-121041 2015-03-11 2015-10-11  Standard Class    CS-12250
#
#      Customer Name    Segment        Country           City  ...  \
# 0     Jamie Kunitz   Consumer  United States  San Francisco  ...
# 1   Michael Nguyen   Consumer  United States        Memphis  ...
# 2  Muhammed Yedwab  Corporate  United States        Chicago  ...
# 3  Jeremy Lonsdale   Consumer  United States  New York City  ...
# 4  Chris Selesnick  Corporate  United States    Haltom City  ...
#
#   Retail Sales People       Product ID         Category Sub-Category  \
# ...

# %%
features = df[['Sales', 'Profit', 'Quantity']]

print(features)
# Out:
#       Sales  Profit  Quantity
# 0     7.420  3.7100         2
# 1     8.904  3.3390         3
# 2     8.904  3.3390         3
# 3     8.260  3.7996         2
# 4     6.608  2.1476         2
# ...     ...     ...       ...
# 9989  1.872 -1.3104         2
# 9990  6.240  3.0576         2
# 9991  6.240  3.0576         2
# 9992  1.248 -1.9344         2
# 9993  2.496  0.9048         1
#
# [9994 rows x 3 columns]

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluster')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# %%
sns.scatterplot(x='Sales', y='Profit', hue='Cluster', data=df, palette='Set2')
plt.title("Visualisasi Cluster Produk berdasarkan Sales & Profit")
plt.show()

# %%
# !pip install openpyxl

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_excel("Dataset.xlsx")

# %%
duplicates = df[df.duplicated()]
print("Duplikat yang ditemukan:\n", duplicates)

df["Order Date"] = pd.to_datetime(df["Order Date"], errors='coerce')
df["Ship Date"] = pd.to_datetime(df["Ship Date"], errors='coerce')

numeric_columns = ["Sales", "Quantity", "Discount", "Profit"]
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

print("Tipe Data Kolom:")
print(df.dtypes)

print("\nMissing Values setelah konversi:")
print(df.isnull().sum())
# Out:
# Duplikat yang ditemukan:
#  Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Retail Sales People, Product ID, Category, Sub-Category, Product Name, Returned, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 23 columns]
# Tipe Data Kolom:
# Row ID                          int64
# Order ID                       object
# Order Date             datetime64[ns]
# Ship Date              datetime64[ns]
# Ship Mode                      object
# Customer ID                    object
# Customer Name                  object
# Segment                        object
# Country                        object
# City                           object
# State                          object
# Postal Code                     int64
# Region                         object
# Retail Sales People            object
# Product ID                     object
# ...

# %%
df_reduced = df[["Sales", "Quantity", "Discount", "Profit", "Product Name"]].dropna()

#Normalisasi data
scaler = MinMaxScaler()
df_reduced = df[["Sales", "Quantity", "Discount", "Profit", "Product Name"]].dropna()

#Normalisasi data
scaler = MinMaxScaler()
df_transformed = df_reduced.copy()
df_transformed[["Sales", "Quantity", "Discount", "Profit"]] = scaler.fit_transform(
    df_transformed[["Sales", "Quantity", "Discount", "Profit"]]
)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)  # ganti jumlah cluster kalau perlu
df_transformed['Cluster'] = kmeans.fit_predict(X)

# %%
X_reg = df_transformed[["Sales", "Quantity", "Discount"]]
y_reg = df_transformed["Profit"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R-Square (R²):", r2)
# Out:
# Mean Squared Error (MSE): 7.941647147956118e-05
# R-Square (R²): 0.41872473398699595

# %%
pd.DataFrame({
    "Fitur": X_train.columns,
    "Koefisien": model.coef_
})
# Out:
#       Fitur  Koefisien
# 0     Sales   0.269323
# 1  Quantity  -0.002681
# 2  Discount  -0.013067
